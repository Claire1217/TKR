# %%
import numpy as np
import os
import nibabel as nib
import matplotlib.pyplot as plt

# %%
img = nib.load('R:\OAIKNEE-Q1126\OAI_Full_Dataset\\0.C.2\9000798\OAI9000798_BaseLine_8se2d7_Sagittal_T2_Map_120mmFOV_RIGHT_e3.nii.gz').get_fdata()

# %%
img2 = nib.load('R:\OAIKNEE-Q1126\OAI_Full_Dataset\\0.C.2\9000798\OAI9000798_BaseLine_3_de3d1_SAG_3D_DESS_WE_LEFT.nii.gz').get_fdata()

# %%
img3 = nib.load('R:\OAIKNEE-Q1126\OAI_Full_Dataset\\0.C.2\9002817\OAI9002817_BaseLine_8se2d7_Sagittal_T2_Map_120mmFOV_RIGHT_e1.nii.gz').get_fdata()

# %%
img4 = nib.load('R:\OAIKNEE-Q1126\OAI_UQ_processed\AKOA_TKR_Data\TKR\OAI9002430_BaseLine_3_de3d1_SAG_3D_DESS_WE_RIGHT.nii.gz').get_fdata()

# %%
plt.imshow(img[:,:,23])

# %%
img4.shape
# Out:
# (160, 384, 384)

# %%
384/2
img_s = img4[80,:,:]
img_s = cv2.normalize(img_s, None, 0,255, cv2.NORM_MINMAX)
img_s=cv2.resize(img_s, (256, 256))

# %%
143//2
# Out:
# 71

# %%
for i in range(10):
    plt.figure()
    plt.imshow(img2[20 + i*10,:,:])

# %%
for i in range(10):
    plt.figure()
    plt.imshow(img2[:,150+5*i,60:220])

# %%
img2[:,180,50:210]
img_s = cv2.normalize(img_s, None, 0,255, cv2.NORM_MINMAX)
# this currently returns shape h x w, need to reshape to torch format bs x 1 x h x w
# return anything you like, remember to unpack appropriately

###
img_s=cv2.resize(img_s, (256, 256))
# Out:
#   File "C:\Users\s4469251\AppData\Local\Temp/ipykernel_19408/651604398.py", line 1
#     img2[:,180,[50:210]]
#                   ^
# SyntaxError: invalid syntax

# %%
# !pip install opencv-python

# %%
import cv2

# %%
img2.shape
# Out:
# (160, 384, 384)

# %%
img3.shape
# Out:
# (384, 384, 27)

# %%
import tkr_generator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24700\4244845319.py in <module>
# ----> 1 import tkr_generator
#
# c:\Users\s4469251\Documents\codes\AKOA_TKR\tkr_generator.py in <module>
#       7 import numpy as np
#       8 import os
# ----> 9 import cv2
#      10 import nibabel as nib
#      11 import subprocess
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv
# Out:
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv
